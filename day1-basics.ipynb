# %% [markdown]
# <a href="https://colab.research.google.com/github/LeenaJayavarshini/python-colab-practice/blob/main/day1-basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, I am learning Python!")
# Out:
# Hello, I am learning Python!

# %%
name = "Leena Jayavarshini P"
age = 20
college = "K.Ramakrishnan College of Technology"
print("My name :",name,"\nMy age :",age,"\nMy college :",college)
# Out:
# My name : Leena Jayavarshini P
# My age : 20
# My college : K.Ramakrishnan College of Technology

# %%
price = 76.6
quantity = 4
print(f"Total:₹{price*quantity}")
# Out:
# Total:₹306.4

# %%
Principal = float(input("Enter Principal: "))
roi = float(input("Enter rate of interest: "))
time = float(input("Enter time: "))
result = (Principal*roi*time)/100
print(f"SI : ₹{result}")
# Out:
# Enter Principal: 5.5
# Enter rate of interest: 2
# Enter time: 4
# SI : ₹0.44

# %%
name = input("Enter name: ")
byear = int(input("Enter birth year: "))
cyear = 2026
age = cyear - byear
print(f"Huii {name}!! you are {age} years old.")
# Out:
# Enter name: Leena
# Enter birth year: 2005
# Huii Leena!! you are 21 years old.
